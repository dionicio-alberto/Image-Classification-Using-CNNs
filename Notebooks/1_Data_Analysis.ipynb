# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
CURRENT_DIR = Path('.').resolve()
MODULES_DIR = CURRENT_DIR.parent.joinpath('src')
sys.path.append(str(MODULES_DIR))
DATA_DIR = CURRENT_DIR.parent.joinpath('Data','Raw')

# %% [markdown]
# ------
#
# # The cats and dogs dataset
#
# The cats and dogs datset is provided by Microsoft.
# Let's plot the images to better understand the kind of data we're working with

# %%
list_cats = []
for archivo in DATA_DIR.joinpath('Cat').rglob('*'):
    if archivo.is_file():
        list_cats.append(archivo)
        
list_dogs = []
for archivo in DATA_DIR.joinpath('Dog').rglob('*'):
    if archivo.is_file():
        list_dogs.append(archivo)

# %%
import visualization as vis

vis.explorer(list_cats,'Cat')
vis.explorer(list_dogs, 'Dog')

# %% [markdown]
# -----
#
# # Managing image data for keras
#
# Keras provides a useful `flow_from_directory` method that takes as an input the path to the images and generates bathces of data as output. The batches of data are loaded into memory, as required before model training.
#
# We are required to create subdirectories for training and testing data, and within the training testing subdirectories. As follows:
#
# ![diagram](https://i.imgur.com/pkI10EO.png)

# %%
import utils

DATA_PROCESS = DATA_DIR.parent.joinpath('Process')
utils.train_test_split(DATA_DIR,DATA_PROCESS,0.8)
